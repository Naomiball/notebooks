# %% [markdown]
# <a href="https://colab.research.google.com/github/Naomiball/notebooks/blob/master/Sercero_Text_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This notebook will show how to build a text claddification based on health_fact dataset on huggingface hub to performe classification task, using one of the pre-trained transformers.

# %% [markdown]
# Install transformers, dataset, scipy and sklearn

# %%
! pip install git+https://github.com/huggingface/transformers.git
! pip install git+https://github.com/huggingface/datasets.git
! pip install scipy sklearn
# Out:
# Collecting git+https://github.com/huggingface/transformers.git
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-h319ltxk
#   Running command git clone -q https://github.com/huggingface/transformers.git /tmp/pip-req-build-h319ltxk
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting huggingface-hub>=0.0.17
#   Downloading huggingface_hub-0.0.19-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 2.5 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.12.0.dev0) (4.8.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.12.0.dev0) (2.23.0)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 10.5 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.12.0.dev0) (4.62.3)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 51.4 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 55.2 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.12.0.dev0) (2019.12.20)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers==4.12.0.dev0) (21.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.12.0.dev0) (1.19.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.12.0.dev0) (3.3.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.17->transformers==4.12.0.dev0) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers==4.12.0.dev0) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.12.0.dev0) (3.6.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.12.0.dev0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.12.0.dev0) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.12.0.dev0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.12.0.dev0) (3.0.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.12.0.dev0) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.12.0.dev0) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.12.0.dev0) (1.15.0)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (PEP 517) ... done
#   Created wheel for transformers: filename=transformers-4.12.0.dev0-py3-none-any.whl size=2984593 sha256=dde407a0f74c67fb788720dcb01eebbe2b431a7637e51c9cd1308630847fb58d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4j2gf23p/wheels/90/a5/44/6bcd83827c8a60628c5ad602f429cd5076bcce5f2a90054947
# Successfully built transformers
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.0.19 pyyaml-6.0 sacremoses-0.0.46 tokenizers-0.10.3 transformers-4.12.0.dev0
# Collecting git+https://github.com/huggingface/datasets.git
#   Cloning https://github.com/huggingface/datasets.git to /tmp/pip-req-build-vcds9dtd
#   Running command git clone -q https://github.com/huggingface/datasets.git /tmp/pip-req-build-vcds9dtd
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets==1.13.4.dev0) (1.19.5)
# Requirement already satisfied: pyarrow!=4.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.13.4.dev0) (3.0.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets==1.13.4.dev0) (0.3.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets==1.13.4.dev0) (1.1.5)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.13.4.dev0) (2.23.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets==1.13.4.dev0) (4.62.3)
# Collecting xxhash
#   Downloading xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243 kB)
#      |████████████████████████████████| 243 kB 5.2 MB/s
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets==1.13.4.dev0) (0.70.12.2)
# Collecting fsspec[http]>=2021.05.0
#   Downloading fsspec-2021.10.1-py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 58.1 MB/s
# Collecting aiohttp
#   Downloading aiohttp-3.7.4.post0-cp37-cp37m-manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 43.0 MB/s
# Requirement already satisfied: huggingface_hub<0.1.0,>=0.0.19 in /usr/local/lib/python3.7/dist-packages (from datasets==1.13.4.dev0) (0.0.19)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets==1.13.4.dev0) (21.0)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.7/dist-packages (from datasets==1.13.4.dev0) (4.8.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface_hub<0.1.0,>=0.0.19->datasets==1.13.4.dev0) (3.3.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from huggingface_hub<0.1.0,>=0.0.19->datasets==1.13.4.dev0) (6.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface_hub<0.1.0,>=0.0.19->datasets==1.13.4.dev0) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets==1.13.4.dev0) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.13.4.dev0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.13.4.dev0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.13.4.dev0) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.13.4.dev0) (3.0.4)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (160 kB)
#      |████████████████████████████████| 160 kB 56.5 MB/s
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 59.2 MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.13.4.dev0) (21.2.0)
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib_metadata->datasets==1.13.4.dev0) (3.6.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets==1.13.4.dev0) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets==1.13.4.dev0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets==1.13.4.dev0) (1.15.0)
# Building wheels for collected packages: datasets
#   Building wheel for datasets (setup.py) ... done
#   Created wheel for datasets: filename=datasets-1.13.4.dev0-py3-none-any.whl size=285554 sha256=0c0972e0b39d8c8e0955577d065441ca61f89252ba93a2ecac0ac99a13007541
#   Stored in directory: /tmp/pip-ephem-wheel-cache-swu37coc/wheels/cc/33/c1/2cacc415b23189a83908e45db67381ba26175ef1e8aa9062aa
# Successfully built datasets
# Installing collected packages: multidict, yarl, async-timeout, fsspec, aiohttp, xxhash, datasets
# Successfully installed aiohttp-3.7.4.post0 async-timeout-3.0.1 datasets-1.13.4.dev0 fsspec-2021.10.1 multidict-5.2.0 xxhash-2.0.2 yarl-1.7.0
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (1.4.1)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (0.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scipy) (1.19.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.0.1)

# %%
# !pip install torch==1.5.1+cpu torchvision==0.6.1+cpu -f https://download.pytorch.org/whl/torch_stable.html -vvv
import torch
print(torch.__version__)
# Out:
# Using pip 21.1.3 from /usr/local/lib/python3.7/dist-packages/pip (python 3.7)
# Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.7/dist-packages
# sysconfig: /usr/lib/python3.7/site-packages
# Value for scheme.purelib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.7/dist-packages
# sysconfig: /usr/lib/python3.7/site-packages
# Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/include/python3.7/UNKNOWN
# sysconfig: /usr/include/python3.7m/UNKNOWN
# Value for scheme.scripts does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/bin
# sysconfig: /usr/bin
# Value for scheme.data does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local
# sysconfig: /usr
# Additional context:
# user = False
# home = None
# root = None
# prefix = None
# Non-user install because site-packages writeable
# Created temporary directory: /tmp/pip-ephem-wheel-cache-s_zuvp_n
# Created temporary directory: /tmp/pip-req-tracker-sf_avy4d
# Initialized build tracking at /tmp/pip-req-tracker-sf_avy4d
# Created build tracker: /tmp/pip-req-tracker-sf_avy4d
# Entered build tracker: /tmp/pip-req-tracker-sf_avy4d
# Created temporary directory: /tmp/pip-install-nkenu1c9
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# 2 location(s) to search for versions of torch:
# * https://download.pytorch.org/whl/torch_stable.html
# * https://pypi.org/simple/torch/
# Fetching project page and analyzing links: https://download.pytorch.org/whl/torch_stable.html
# Getting page https://download.pytorch.org/whl/torch_stable.html
# Looking up "https://download.pytorch.org/whl/torch_stable.html" in the cache
# Request header has "max_age" as 0, cache bypassed
# Starting new HTTPS connection (1): download.pytorch.org:443
# https://download.pytorch.org:443 "GET /whl/torch_stable.html HTTP/1.1" 200 227639
# Updating cache with response from "https://download.pytorch.org/whl/torch_stable.html"
# Response header has "no-store"
#   Skipping link: none of the wheel's tags (cp27-cp27m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-0.3.0.post4-cp27-cp27m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-cp27mu-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-0.3.0.post4-cp27-cp27mu-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-cp35m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-0.3.0.post4-cp35-cp35m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-0.3.0.post4-cp36-cp36m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-cp27m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-0.3.1-cp27-cp27m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-cp27mu-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-0.3.1-cp27-cp27mu-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-cp35m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-0.3.1-cp35-cp35m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-0.3.1-cp36-cp36m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-cp27m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-0.4.0-cp27-cp27m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-cp27mu-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-0.4.0-cp27-cp27mu-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-cp35m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-0.4.0-cp35-cp35m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-cp35m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-0.4.0-cp35-cp35m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-0.4.0-cp36-cp36m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-0.4.0-cp36-cp36m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-cp27m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-0.4.1-cp27-cp27m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-cp27mu-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-0.4.1-cp27-cp27mu-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-cp35m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-0.4.1-cp35-cp35m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-cp35m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-0.4.1-cp35-cp35m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-0.4.1-cp36-cp36m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-0.4.1-cp36-cp36m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Found link https://download.pytorch.org/whl/cpu/torch-0.4.1-cp37-cp37m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html), version: 0.4.1
#   Skipping link: none of the wheel's tags (cp37-cp37m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-0.4.1-cp37-cp37m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Found link https://download.pytorch.org/whl/cpu/torch-0.4.1.post2-cp37-cp37m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html), version: 0.4.1.post2
#   Skipping link: none of the wheel's tags (cp27-cp27m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.0.0-cp27-cp27m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-cp27mu-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.0.0-cp27-cp27mu-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-none-macosx_10_6_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.0.0-cp27-none-macosx_10_6_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-cp35m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.0.0-cp35-cp35m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-cp35m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.0.0-cp35-cp35m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-none-macosx_10_6_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.0.0-cp35-none-macosx_10_6_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.0.0-cp36-cp36m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.0.0-cp36-cp36m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-none-macosx_10_7_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.0.0-cp36-none-macosx_10_7_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Found link https://download.pytorch.org/whl/cpu/torch-1.0.0-cp37-cp37m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html), version: 1.0.0
#   Skipping link: none of the wheel's tags (cp37-cp37m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.0.0-cp37-cp37m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp37-none-macosx_10_7_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.0.0-cp37-none-macosx_10_7_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-cp27m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.0.1-cp27-cp27m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-cp27mu-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.0.1-cp27-cp27mu-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-none-macosx_10_6_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.0.1-cp27-none-macosx_10_6_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-cp35m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.0.1-cp35-cp35m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-cp35m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.0.1-cp35-cp35m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-none-macosx_10_6_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.0.1-cp35-none-macosx_10_6_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.0.1-cp36-cp36m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.0.1-cp36-cp36m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-none-macosx_10_7_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.0.1-cp36-none-macosx_10_7_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Found link https://download.pytorch.org/whl/cpu/torch-1.0.1-cp37-cp37m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html), version: 1.0.1
#   Skipping link: none of the wheel's tags (cp37-cp37m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.0.1-cp37-cp37m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp37-none-macosx_10_7_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.0.1-cp37-none-macosx_10_7_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-cp27m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.0.1.post2-cp27-cp27m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-cp27mu-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.0.1.post2-cp27-cp27mu-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-cp35m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.0.1.post2-cp35-cp35m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.0.1.post2-cp36-cp36m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Found link https://download.pytorch.org/whl/cpu/torch-1.0.1.post2-cp37-cp37m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html), version: 1.0.1.post2
#   Skipping link: none of the wheel's tags (cp27-cp27m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.1.0-cp27-cp27m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-cp27mu-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.1.0-cp27-cp27mu-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-none-macosx_10_6_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.1.0-cp27-none-macosx_10_6_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-cp35m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.1.0-cp35-cp35m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-cp35m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.1.0-cp35-cp35m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-none-macosx_10_6_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.1.0-cp35-none-macosx_10_6_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.1.0-cp36-cp36m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.1.0-cp36-cp36m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-none-macosx_10_7_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.1.0-cp36-none-macosx_10_7_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Found link https://download.pytorch.org/whl/cpu/torch-1.1.0-cp37-cp37m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html), version: 1.1.0
#   Skipping link: none of the wheel's tags (cp37-cp37m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.1.0-cp37-cp37m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp37-none-macosx_10_7_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.1.0-cp37-none-macosx_10_7_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-none-macosx_10_6_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.1.0.post2-cp27-none-macosx_10_6_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-none-macosx_10_6_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.1.0.post2-cp35-none-macosx_10_6_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-none-macosx_10_7_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.1.0.post2-cp36-none-macosx_10_7_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp37-none-macosx_10_7_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.1.0.post2-cp37-none-macosx_10_7_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-cp27m-manylinux1_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.2.0%2Bcpu-cp27-cp27m-manylinux1_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-cp27mu-manylinux1_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.2.0%2Bcpu-cp27-cp27mu-manylinux1_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-cp35m-manylinux1_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.2.0%2Bcpu-cp35-cp35m-manylinux1_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-cp35m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.2.0%2Bcpu-cp35-cp35m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-manylinux1_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.2.0%2Bcpu-cp36-cp36m-manylinux1_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.2.0%2Bcpu-cp36-cp36m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Found link https://download.pytorch.org/whl/cpu/torch-1.2.0%2Bcpu-cp37-cp37m-manylinux1_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html), version: 1.2.0+cpu
#   Skipping link: none of the wheel's tags (cp37-cp37m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.2.0%2Bcpu-cp37-cp37m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-none-macosx_10_6_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.2.0-cp27-none-macosx_10_6_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-none-macosx_10_6_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.2.0-cp35-none-macosx_10_6_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-none-macosx_10_7_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.2.0-cp36-none-macosx_10_7_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp37-none-macosx_10_7_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.2.0-cp37-none-macosx_10_7_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-cp27m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.3.0%2Bcpu-cp27-cp27m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-cp27mu-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.3.0%2Bcpu-cp27-cp27mu-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-cp35m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.3.0%2Bcpu-cp35-cp35m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-cp35m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.3.0%2Bcpu-cp35-cp35m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.3.0%2Bcpu-cp36-cp36m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.3.0%2Bcpu-cp36-cp36m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Found link https://download.pytorch.org/whl/cpu/torch-1.3.0%2Bcpu-cp37-cp37m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html), version: 1.3.0+cpu
#   Skipping link: none of the wheel's tags (cp37-cp37m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.3.0%2Bcpu-cp37-cp37m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-none-macosx_10_6_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.3.0-cp35-none-macosx_10_6_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-none-macosx_10_7_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.3.0-cp36-none-macosx_10_7_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp37-none-macosx_10_9_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.3.0-cp37-none-macosx_10_9_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-none-macosx_10_7_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.3.0.post2-cp27-none-macosx_10_7_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-none-macosx_10_6_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.3.0.post2-cp35-none-macosx_10_6_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-none-macosx_10_7_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.3.0.post2-cp36-none-macosx_10_7_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp37-none-macosx_10_9_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.3.0.post2-cp37-none-macosx_10_9_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-cp27m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.3.1%2Bcpu-cp27-cp27m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-cp27mu-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.3.1%2Bcpu-cp27-cp27mu-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-cp35m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.3.1%2Bcpu-cp35-cp35m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-cp35m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.3.1%2Bcpu-cp35-cp35m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.3.1%2Bcpu-cp36-cp36m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.3.1%2Bcpu-cp36-cp36m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Found link https://download.pytorch.org/whl/cpu/torch-1.3.1%2Bcpu-cp37-cp37m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html), version: 1.3.1+cpu
#   Skipping link: none of the wheel's tags (cp37-cp37m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.3.1%2Bcpu-cp37-cp37m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-none-macosx_10_7_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.3.1-cp27-none-macosx_10_7_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-none-macosx_10_6_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.3.1-cp35-none-macosx_10_6_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-none-macosx_10_7_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.3.1-cp36-none-macosx_10_7_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp37-none-macosx_10_7_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.3.1-cp37-none-macosx_10_7_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-cp27m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.4.0%2Bcpu-cp27-cp27m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-cp27mu-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.4.0%2Bcpu-cp27-cp27mu-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-cp35m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.4.0%2Bcpu-cp35-cp35m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-cp35m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.4.0%2Bcpu-cp35-cp35m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.4.0%2Bcpu-cp36-cp36m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.4.0%2Bcpu-cp36-cp36m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Found link https://download.pytorch.org/whl/cpu/torch-1.4.0%2Bcpu-cp37-cp37m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html), version: 1.4.0+cpu
#   Skipping link: none of the wheel's tags (cp37-cp37m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.4.0%2Bcpu-cp37-cp37m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp38-cp38-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.4.0%2Bcpu-cp38-cp38-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp38-cp38-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.4.0%2Bcpu-cp38-cp38-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-none-macosx_10_7_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.4.0-cp27-none-macosx_10_7_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-none-macosx_10_6_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.4.0-cp35-none-macosx_10_6_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-none-macosx_10_7_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.4.0-cp36-none-macosx_10_7_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-none-macosx_10_9_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.4.0-cp36-none-macosx_10_9_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp37-none-macosx_10_7_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.4.0-cp37-none-macosx_10_7_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp37-none-macosx_10_9_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.4.0-cp37-none-macosx_10_9_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp38-none-macosx_10_9_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.4.0-cp38-none-macosx_10_9_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-cp27m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.5.0%2Bcpu-cp27-cp27m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-cp27mu-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.5.0%2Bcpu-cp27-cp27mu-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-cp35m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.5.0%2Bcpu-cp35-cp35m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-cp35m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.5.0%2Bcpu-cp35-cp35m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.5.0%2Bcpu-cp36-cp36m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.5.0%2Bcpu-cp36-cp36m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Found link https://download.pytorch.org/whl/cpu/torch-1.5.0%2Bcpu-cp37-cp37m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html), version: 1.5.0+cpu
#   Skipping link: none of the wheel's tags (cp37-cp37m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.5.0%2Bcpu-cp37-cp37m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp38-cp38-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.5.0%2Bcpu-cp38-cp38-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp38-cp38-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.5.0%2Bcpu-cp38-cp38-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp27-none-macosx_10_7_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.5.0-cp27-none-macosx_10_7_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-none-macosx_10_6_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.5.0-cp35-none-macosx_10_6_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-none-macosx_10_9_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.5.0-cp36-none-macosx_10_9_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp37-none-macosx_10_9_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.5.0-cp37-none-macosx_10_9_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp38-none-macosx_10_9_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.5.0-cp38-none-macosx_10_9_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-cp35m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.5.1%2Bcpu-cp35-cp35m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-cp35m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.5.1%2Bcpu-cp35-cp35m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.5.1%2Bcpu-cp36-cp36m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.5.1%2Bcpu-cp36-cp36m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Found link https://download.pytorch.org/whl/cpu/torch-1.5.1%2Bcpu-cp37-cp37m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html), version: 1.5.1+cpu
#   Skipping link: none of the wheel's tags (cp37-cp37m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.5.1%2Bcpu-cp37-cp37m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp38-cp38-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.5.1%2Bcpu-cp38-cp38-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp38-cp38-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.5.1%2Bcpu-cp38-cp38-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp35-none-macosx_10_6_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.5.1-cp35-none-macosx_10_6_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-none-macosx_10_9_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.5.1-cp36-none-macosx_10_9_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp37-none-macosx_10_9_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.5.1-cp37-none-macosx_10_9_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp38-none-macosx_10_9_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.5.1-cp38-none-macosx_10_9_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.6.0%2Bcpu-cp36-cp36m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.6.0%2Bcpu-cp36-cp36m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Found link https://download.pytorch.org/whl/cpu/torch-1.6.0%2Bcpu-cp37-cp37m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html), version: 1.6.0+cpu
#   Skipping link: none of the wheel's tags (cp37-cp37m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.6.0%2Bcpu-cp37-cp37m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp38-cp38-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.6.0%2Bcpu-cp38-cp38-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp38-cp38-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.6.0%2Bcpu-cp38-cp38-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-none-macosx_10_9_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.6.0-cp36-none-macosx_10_9_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp37-none-macosx_10_9_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.6.0-cp37-none-macosx_10_9_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp38-none-macosx_10_9_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.6.0-cp38-none-macosx_10_9_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.7.0%2Bcpu-cp36-cp36m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-cp36m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.7.0%2Bcpu-cp36-cp36m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Found link https://download.pytorch.org/whl/cpu/torch-1.7.0%2Bcpu-cp37-cp37m-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html), version: 1.7.0+cpu
#   Skipping link: none of the wheel's tags (cp37-cp37m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.7.0%2Bcpu-cp37-cp37m-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp38-cp38-linux_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.7.0%2Bcpu-cp38-cp38-linux_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp38-cp38-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.7.0%2Bcpu-cp38-cp38-win_amd64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-none-macosx_10_9_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.7.0-cp36-none-macosx_10_9_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp36-none-macosx_11_0_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.7.0-cp36-none-macosx_11_0_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp37-none-macosx_10_9_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.7.0-cp37-none-macosx_10_9_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp37-none-macosx_11_0_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.7.0-cp37-none-macosx_11_0_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp38-none-macosx_10_9_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.7.0-cp38-none-macosx_10_9_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
#   Skipping link: none of the wheel's tags (cp38-none-macosx_11_0_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://download.pytorch.org/whl/cpu/torch-1.7.0-cp38-none-macosx_11_0_x86_64.whl (from https://download.pytorch.org/whl/torch_stable.html)
# ...
#   Skipping link: none of the wheel's tags (cp38-cp38-macosx_10_9_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/a6/e1/97492d5dba950d6a84d7c5d6ab2fe1cfe5b091ed02bd8e39b8931ffbac95/torchvision-0.10.0-cp38-cp38-macosx_10_9_x86_64.whl#sha256=ad24107b2ed0ccc372af92822f1f8f5530907b6fb7520a08195cf0bb07446923 (from https://pypi.org/simple/torchvision/)
#   Skipping link: none of the wheel's tags (cp38-cp38-macosx_11_0_arm64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/73/09/eb3546fb8b76f7b12861bad9de430766d4995347b22cdad547fb5e9fdb04/torchvision-0.10.0-cp38-cp38-macosx_11_0_arm64.whl#sha256=bb04708354fb6d639f6e47d8066b0d546fbe0a3a68685cf8d413a6370c8f63ad (from https://pypi.org/simple/torchvision/)
#   Skipping link: none of the wheel's tags (cp38-cp38-manylinux1_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/3a/8e/a6e1b4781c4ed2fa3a541e5fb4be1abacb9aa694b508fc8b1c027ee420e7/torchvision-0.10.0-cp38-cp38-manylinux1_x86_64.whl#sha256=aa709fa63896f93e03a03976230a51050fcd5f1b45cf663f62d91b7eaaf8ac09 (from https://pypi.org/simple/torchvision/)
#   Skipping link: none of the wheel's tags (cp38-cp38-manylinux2014_aarch64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/35/4d/1c069e8b325904c106e16c74705eb972bf0b68a70509d517ed81f43aeee8/torchvision-0.10.0-cp38-cp38-manylinux2014_aarch64.whl#sha256=4796e1fb2995c6e495c5ea4e2b0fe0e4be44bd9416ef4a1349c1a406675cbdee (from https://pypi.org/simple/torchvision/)
#   Skipping link: none of the wheel's tags (cp38-cp38-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/a9/43/16687a60d97b654d74e3410f68ec3f9aeb8bdad95c68ffc58b5a7fb02854/torchvision-0.10.0-cp38-cp38-win_amd64.whl#sha256=487bbfd89575a52cd18bca8a33e24c373570e060f801265051c3a0aafc769720 (from https://pypi.org/simple/torchvision/)
#   Skipping link: none of the wheel's tags (cp39-cp39-macosx_10_9_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/76/e6/7be72bbc5fa95a3c5f9690576bed1de45570f5f550a869bb19772f82d4c5/torchvision-0.10.0-cp39-cp39-macosx_10_9_x86_64.whl#sha256=f68291559a4cf1245c95efc5e47ebe158819aceec4e1f585d2fe133cd2c9d8e8 (from https://pypi.org/simple/torchvision/)
#   Skipping link: none of the wheel's tags (cp39-cp39-macosx_11_0_arm64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/7c/79/46d770d340a5e57b711745e3cf4f11e9478c411ea33bf8bccf3d6b3fde9b/torchvision-0.10.0-cp39-cp39-macosx_11_0_arm64.whl#sha256=ae9606cc248de9b3a077710529b11c57315d2914c8ee3099fbd93a62f56a1661 (from https://pypi.org/simple/torchvision/)
#   Skipping link: none of the wheel's tags (cp39-cp39-manylinux1_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/00/03/88edb6f9f7f17ce264a01209ac550878713a66a99d9d8e25747b15d6aadb/torchvision-0.10.0-cp39-cp39-manylinux1_x86_64.whl#sha256=20a57ce42fa20c26d800c65d5b88dbaaa115a01f4f5623d41abfb182b854f199 (from https://pypi.org/simple/torchvision/)
#   Skipping link: none of the wheel's tags (cp39-cp39-manylinux2014_aarch64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/88/92/c00de7e23b1b2878cd175abb63ec8c2189761a076be0d9c15e6be98cd451/torchvision-0.10.0-cp39-cp39-manylinux2014_aarch64.whl#sha256=a30466893a5b97073c992859f3645e3e1f41daf2c1b4db6cb2ac8ec7d0e1f6bc (from https://pypi.org/simple/torchvision/)
#   Skipping link: none of the wheel's tags (cp39-cp39-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/76/35/7fa3abe6a58a9c1270533c7b56ba2b6d8f25216e54299f2be6cd65443ec8/torchvision-0.10.0-cp39-cp39-win_amd64.whl#sha256=da65af25b51caf43327ecb3ccf550eedfd62d1f73511db44370b4b9522569b8d (from https://pypi.org/simple/torchvision/)
#   Skipping link: none of the wheel's tags (cp36-cp36m-macosx_10_9_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/73/42/98bfffa67cfc4bb4f373f4115e6314d4ae221f0669281c9dfb69366eb16a/torchvision-0.10.1-cp36-cp36m-macosx_10_9_x86_64.whl#sha256=bc99a984b162ee5626787eaee885d9fec1a5f16837f9d0c8223cca3269b9e47d (from https://pypi.org/simple/torchvision/)
#   Skipping link: none of the wheel's tags (cp36-cp36m-manylinux1_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/8e/3b/73e2cf095f0a9d0f26b008cbfc009512c53bb2a445723aaad54b33e58cb5/torchvision-0.10.1-cp36-cp36m-manylinux1_x86_64.whl#sha256=46a70a30ea7aeab63e67504778f2565fbb1c153fdd8e1a8c6a22193aec4dbddd (from https://pypi.org/simple/torchvision/)
#   Skipping link: none of the wheel's tags (cp36-cp36m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/8b/3d/207d7ff1c41dc2bdc5f322828531cda9ce361203866855bd64c20dbb06f7/torchvision-0.10.1-cp36-cp36m-win_amd64.whl#sha256=e504d9d51eae60a98925aee4a3fd58655abd5669659ad7431f7791a93af166fc (from https://pypi.org/simple/torchvision/)
#   Skipping link: none of the wheel's tags (cp37-cp37m-macosx_10_9_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/39/6b/5c93b16c43cb157851afda3568ef9f72818e9f622cc310904b6ad1543f72/torchvision-0.10.1-cp37-cp37m-macosx_10_9_x86_64.whl#sha256=cd7e2b1a89d5a08f24325fc12441f5ba2822f407489377ac7841bf351a1f4d37 (from https://pypi.org/simple/torchvision/)
#   Found link https://files.pythonhosted.org/packages/56/6c/daa50a536812da895a4eecaefdffbffd90736c47898d942501080a5b42a5/torchvision-0.10.1-cp37-cp37m-manylinux1_x86_64.whl#sha256=99d3e01e1d67d12bcc88e826431b70cad5b8e4729a277c04601f83358a120508 (from https://pypi.org/simple/torchvision/), version: 0.10.1
#   Skipping link: none of the wheel's tags (cp37-cp37m-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/a9/fb/2329c2ddb214336524b7abcae046c69fdaa17f8d6b34462c8155490711e7/torchvision-0.10.1-cp37-cp37m-win_amd64.whl#sha256=4ebffeee5468a0934952030eaba1de1dbb08154132235ee1d9049e41dfb1600d (from https://pypi.org/simple/torchvision/)
#   Skipping link: none of the wheel's tags (cp38-cp38-macosx_10_9_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/ed/6e/a3d9945e12468735ea5503f2501260d3d2532bdf039bbce68eafb0f6c38d/torchvision-0.10.1-cp38-cp38-macosx_10_9_x86_64.whl#sha256=d7c2d6c20244404fc9ca3568c88c305cb5a81d526d5912d52d22c64999bd4353 (from https://pypi.org/simple/torchvision/)
#   Skipping link: none of the wheel's tags (cp38-cp38-manylinux1_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/4b/9b/3eac77b49101cb731725c113a41f6355f316aed47a3a48964c9e95e0e3b7/torchvision-0.10.1-cp38-cp38-manylinux1_x86_64.whl#sha256=d6420bf21b9d0bdbabe55d64c8b11c61f8eb077948a55d5707946fcb17d97cec (from https://pypi.org/simple/torchvision/)
#   Skipping link: none of the wheel's tags (cp38-cp38-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/33/59/047bdb8c3dd2bc34e6e20cde495b6317605422f8d4c718430866fc28c171/torchvision-0.10.1-cp38-cp38-win_amd64.whl#sha256=453e935212193e89b4bbb8d51082d8138631c2f8a420390284b1946d893df6eb (from https://pypi.org/simple/torchvision/)
#   Skipping link: none of the wheel's tags (cp39-cp39-macosx_10_9_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/4b/13/6259967e57bc1c8f7bfc8fddbd0b79ef9a31297403736e4a7c927c22d81a/torchvision-0.10.1-cp39-cp39-macosx_10_9_x86_64.whl#sha256=1c186f42b4f8aa9a01c56c3a758693b0447aa169afb9fba0051177f8fecbd691 (from https://pypi.org/simple/torchvision/)
#   Skipping link: none of the wheel's tags (cp39-cp39-manylinux1_x86_64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/e7/cd/701539d8763529861f3bb76b90f7cbedb2edc7920101d9772fd77b921cf1/torchvision-0.10.1-cp39-cp39-manylinux1_x86_64.whl#sha256=ac8dfbe4933013dda898b815e2476ebbc35e3a16b9352dfdd66e773c77755bec (from https://pypi.org/simple/torchvision/)
#   Skipping link: none of the wheel's tags (cp39-cp39-win_amd64) are compatible (run pip debug --verbose to show compatible tags): https://files.pythonhosted.org/packages/a5/84/f3a7889475114eac2e6f2a83c115ece887474389a6c866b3ebfc0e89e364/torchvision-0.10.1-cp39-cp39-win_amd64.whl#sha256=6c8fe90213be4bce590ac9647b34db022d5d1ae94f309a733b9a64e65232173a (from https://pypi.org/simple/torchvision/)
# Skipping link: not a file: https://pypi.org/simple/torchvision/
# Given no hashes to check 1 links for project 'torchvision': discarding no candidates
# Collecting torchvision==0.6.1+cpu
#   Created temporary directory: /tmp/pip-unpack-r1x02hb8
#   Looking up "https://download.pytorch.org/whl/cpu/torchvision-0.6.1%2Bcpu-cp37-cp37m-linux_x86_64.whl" in the cache
#   No cache entry available
#   https://download.pytorch.org:443 "GET /whl/cpu/torchvision-0.6.1%2Bcpu-cp37-cp37m-linux_x86_64.whl HTTP/1.1" 200 5738469
#   Downloading https://download.pytorch.org/whl/cpu/torchvision-0.6.1%2Bcpu-cp37-cp37m-linux_x86_64.whl (5.7 MB)
#      |████████████████████████████████| 5.7 MB 48.0 MB/s eta 0:00:01  Updating cache with response from "https://download.pytorch.org/whl/cpu/torchvision-0.6.1%2Bcpu-cp37-cp37m-linux_x86_64.whl"
#   Caching due to etag
#      |████████████████████████████████| 5.7 MB 48.0 MB/s
#   Added torchvision==0.6.1+cpu from https://download.pytorch.org/whl/cpu/torchvision-0.6.1%2Bcpu-cp37-cp37m-linux_x86_64.whl to build tracker '/tmp/pip-req-tracker-sf_avy4d'
#   Removed torchvision==0.6.1+cpu from https://download.pytorch.org/whl/cpu/torchvision-0.6.1%2Bcpu-cp37-cp37m-linux_x86_64.whl from build tracker '/tmp/pip-req-tracker-sf_avy4d'
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from torch==1.5.1+cpu) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch==1.5.1+cpu) (1.19.5)
# Given no hashes to check 1 links for project 'torch': discarding no candidates
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.6.1+cpu) (7.1.2)
# Created temporary directory: /tmp/pip-unpack-n988ryje
# Installing collected packages: torch, torchvision
#   Attempting uninstall: torch
#     Found existing installation: torch 1.9.0+cu111
#     Uninstalling torch-1.9.0+cu111:
#       Created temporary directory: /tmp/pip-uninstall-17ypscbp
#       Removing file or directory /usr/local/bin/convert-caffe2-to-onnx
#       Removing file or directory /usr/local/bin/convert-onnx-to-caffe2
#       Created temporary directory: /usr/local/lib/python3.7/dist-packages/~affe2
#       Removing file or directory /usr/local/lib/python3.7/dist-packages/caffe2/
#       Created temporary directory: /usr/local/lib/python3.7/dist-packages/~orch-1.9.0+cu111.dist-info
#       Removing file or directory /usr/local/lib/python3.7/dist-packages/torch-1.9.0+cu111.dist-info/
#       Created temporary directory: /usr/local/lib/python3.7/dist-packages/~orch
#       Removing file or directory /usr/local/lib/python3.7/dist-packages/torch/
#       Successfully uninstalled torch-1.9.0+cu111
#   Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/lib/python3.7/dist-packages
#   sysconfig: /usr/lib/python3.7/site-packages
#   Value for scheme.purelib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/lib/python3.7/dist-packages
#   sysconfig: /usr/lib/python3.7/site-packages
#   Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/include/python3.7/torch
#   sysconfig: /usr/include/python3.7m/torch
#   Value for scheme.scripts does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/bin
#   sysconfig: /usr/bin
#   Value for scheme.data does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local
#   sysconfig: /usr
#   Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = None
#
#   changing mode of /usr/local/bin/convert-caffe2-to-onnx to 755
#   changing mode of /usr/local/bin/convert-onnx-to-caffe2 to 755
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.10.0+cu111
#     Uninstalling torchvision-0.10.0+cu111:
#       Created temporary directory: /usr/local/lib/python3.7/dist-packages/~orchvision-0.10.0+cu111.dist-info
#       Removing file or directory /usr/local/lib/python3.7/dist-packages/torchvision-0.10.0+cu111.dist-info/
#       Created temporary directory: /usr/local/lib/python3.7/dist-packages/~orchvision.libs
#       Removing file or directory /usr/local/lib/python3.7/dist-packages/torchvision.libs/
#       Created temporary directory: /usr/local/lib/python3.7/dist-packages/~orchvision
#       Removing file or directory /usr/local/lib/python3.7/dist-packages/torchvision/
#       Successfully uninstalled torchvision-0.10.0+cu111
#   Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/lib/python3.7/dist-packages
#   sysconfig: /usr/lib/python3.7/site-packages
#   Value for scheme.purelib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/lib/python3.7/dist-packages
#   sysconfig: /usr/lib/python3.7/site-packages
#   Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/include/python3.7/torchvision
#   sysconfig: /usr/include/python3.7m/torchvision
#   Value for scheme.scripts does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/bin
#   sysconfig: /usr/bin
#   Value for scheme.data does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local
#   sysconfig: /usr
#   Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = None
#
# Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.7/dist-packages
# sysconfig: /usr/lib/python3.7/site-packages
# Value for scheme.purelib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.7/dist-packages
# sysconfig: /usr/lib/python3.7/site-packages
# Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/include/python3.7/UNKNOWN
# sysconfig: /usr/include/python3.7m/UNKNOWN
# Value for scheme.scripts does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/bin
# sysconfig: /usr/bin
# Value for scheme.data does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local
# sysconfig: /usr
# Additional context:
# user = False
# home = None
# root = None
# prefix = None
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.10.0 requires torch==1.9.0, but you have torch 1.5.1+cpu which is incompatible.
# Successfully installed torch-1.5.1+cpu torchvision-0.6.1+cpu
# Removed build tracker: '/tmp/pip-req-tracker-sf_avy4d'
# 1.5.1+cpu

# %% [markdown]
# Install Git-LFS and setup Git

# %%
# !apt install git-lfs
# !git config --global user.email "totoshuang@yahoo.com"
# !git config --global user.name "Naomiball"
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   git-lfs
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 2,129 kB of archives.
# After this operation, 7,662 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 git-lfs amd64 2.3.4-1 [2,129 kB]
# Fetched 2,129 kB in 1s (2,391 kB/s)
# Selecting previously unselected package git-lfs.
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../git-lfs_2.3.4-1_amd64.deb ...
# Unpacking git-lfs (2.3.4-1) ...
# Setting up git-lfs (2.3.4-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %% [markdown]
# Check version of Transformers:

# %%
import transformers

print(transformers.__version__)
# Out:
# 4.12.0.dev0

# %% [markdown]
# ## Loading the dataset

# %%
import datasets
ds_list = datasets.list_datasets()
[ds for ds in ds_list if "health_fact" in ds]
# Out:
# ['health_fact']

# %%
dataset = datasets.load_dataset("health_fact")
# Out:
# Using custom data configuration default
# Downloading and preparing dataset health_fact/default (download: 23.74 MiB, generated: 64.34 MiB, post-processed: Unknown size, total: 88.08 MiB) to /root/.cache/huggingface/datasets/health_fact/default/1.1.0/99503637e4255bd805f84d57031c18fe4dd88298f00299d56c94fc59ed68ec19...
# Downloading:   0%|          | 0.00/24.9M [00:00<?, ?B/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Dataset health_fact downloaded and prepared to /root/.cache/huggingface/datasets/health_fact/default/1.1.0/99503637e4255bd805f84d57031c18fe4dd88298f00299d56c94fc59ed68ec19. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# # Explore Dataset

# %%
#type(dataset)
type(dataset['train'])
# Out:
# datasets.arrow_dataset.Dataset

# %%
dataset['train'].features
# Out:
# {'claim': Value(dtype='string', id=None),
#  'claim_id': Value(dtype='string', id=None),
#  'date_published': Value(dtype='string', id=None),
#  'explanation': Value(dtype='string', id=None),
#  'fact_checkers': Value(dtype='string', id=None),
#  'label': ClassLabel(num_classes=4, names=['false', 'mixture', 'true', 'unproven'], names_file=None, id=None),
#  'main_text': Value(dtype='string', id=None),
#  'sources': Value(dtype='string', id=None),
#  'subjects': Value(dtype='string', id=None)}

# %%
# check the length of main text from dataset
from pandas import Series
text_len = [len(text) for text in dataset['train']['claim']]
Series(text_len).describe()
# Out:
# count    9832.000000
# mean       87.992372
# std        96.687607
# min         0.000000
# 25%        57.000000
# 50%        68.000000
# 75%       105.000000
# max      4925.000000
# dtype: float64

# %% [markdown]
# There exist observations with target labeled as "-1" which seems like a mistake to me, so some data cleaning need to be done here.

# %%
new_dataset = dataset['train']
targets = set(new_dataset['label'])
print("targets:{}".format(targets))

# Use train_test_split function to first remove all '-1' labels, then applie split
# again to prepare for training
new_dataset = new_dataset.sort('label')
new_dataset = new_dataset.train_test_split(test_size=0.995, shuffle=False)
print(set(new_dataset['test']['label']))

dataset = new_dataset['test'].train_test_split(test_size=0.1)
# Out:
# targets:{0, 1, 2, 3, -1}
# {0, 1, 2, 3}

# %% [markdown]
# By analyzing the length of the claims, I decided to set maximum length equals to 128 for our model, which means the rest of the text will be truncated. Later in the tuning process, I will increase that parameter for better performance if needed

# %%
# define base model and parameters
model_checkpoint = "distilbert-base-uncased"
max_length = 128
batch_size = 16

# %% [markdown]
# ## Preprocessing the data

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

def tokenize_function(corpus):
    return tokenizer(
        corpus['claim'], padding="max_length", truncation=True, max_length=max_length
    )

tokenized_datasets = dataset.map(tokenize_function)
print(tokenized_datasets.column_names)
# Out:
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
#   0%|          | 0/8804 [00:00<?, ?ex/s]
#   0%|          | 0/979 [00:00<?, ?ex/s]
# {'train': ['claim_id', 'claim', 'date_published', 'explanation', 'fact_checkers', 'main_text', 'sources', 'label', 'subjects', 'input_ids', 'attention_mask'], 'test': ['claim_id', 'claim', 'date_published', 'explanation', 'fact_checkers', 'main_text', 'sources', 'label', 'subjects', 'input_ids', 'attention_mask']}

# %%
tokenized_datasets = tokenized_datasets.remove_columns(['date_published', 'explanation',
                                         'fact_checkers', 'main_text', 'sources', 'subjects'])
tokenized_datasets = tokenized_datasets.rename_column('label', 'labels')
tokenized_datasets = tokenized_datasets.with_format("torch")
tokenized_datasets["train"]
# Out:
# Dataset({
#     features: ['claim_id', 'claim', 'labels', 'input_ids', 'attention_mask'],
#     num_rows: 8804
# })

# %% [markdown]
# ## Fine-tuning the model

# %%
from transformers import AutoModelForSequenceClassification

model = AutoModelForSequenceClassification.from_pretrained(model_checkpoint, num_labels=4)
# Out:
# Downloading:   0%|          | 0.00/256M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_projector.bias', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_transform.weight', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'pre_classifier.bias', 'classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# define args for trainer
from transformers import TrainingArguments

training_args = TrainingArguments(
    "test-trainer",
    evaluation_strategy='epoch',
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=5,
    learning_rate=2e-5,
    weight_decay=0.01
)

# %%
from transformers import Trainer
import numpy as np
from torch import nn
from sklearn import preprocessing
from datasets import load_metric

# To run the whole dataset requires to many computing power and time, thus I created
# a smaller dataset for training purpose
small_train_dataset = tokenized_datasets["train"].shuffle(seed=42).select(range(2000))
small_test_dataset = tokenized_datasets["test"].shuffle(seed=42).select(range(200))

# Define metrics 

metric = load_metric("accuracy")

def compute_metrics(eval_preds):
    logits, labels_pred = eval_preds
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels_pred)

# initiate a training class
trainer = Trainer(
    model,
    training_args,
    train_dataset = small_train_dataset,
    eval_dataset = small_test_dataset,
    tokenizer = tokenizer,
    compute_metrics = compute_metrics
)

# training
trainer.train()
# Out:
# Downloading:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# The following columns in the training set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: claim, claim_id.
# ***** Running training *****
#   Num examples = 2000
#   Num Epochs = 5
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 625
#     <div>
#
#       <progress value='337' max='625' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [337/625 58:57 < 50:40, 0.09 it/s, Epoch 2.69/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.788918</td>
#       <td>0.670000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.759135</td>
#       <td>0.675000</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: claim, claim_id.
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 16
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: claim, claim_id.
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 16
#     <div>
#
#       <progress value='625' max='625' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [625/625 1:50:58, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.788918</td>
#       <td>0.670000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.759135</td>
#       <td>0.675000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.759955</td>
#       <td>0.680000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.776300</td>
#       <td>0.830315</td>
#       <td>0.685000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.776300</td>
#       <td>0.821917</td>
#       <td>0.700000</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: claim, claim_id.
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 16
# Saving model checkpoint to test-trainer/checkpoint-500
# Configuration saved in test-trainer/checkpoint-500/config.json
# Model weights saved in test-trainer/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in test-trainer/checkpoint-500/tokenizer_config.json
# Special tokens file saved in test-trainer/checkpoint-500/special_tokens_map.json
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: claim, claim_id.
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 16
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: claim, claim_id.
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 16
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=625, training_loss=0.7272814208984375, metrics={'train_runtime': 6669.9403, 'train_samples_per_second': 1.499, 'train_steps_per_second': 0.094, 'total_flos': 331180308480000.0, 'train_loss': 0.7272814208984375, 'epoch': 5.0})

# %% [markdown]
# Conclusion: With a training set of size 2000 corps, we built a model to classify claims with accuracy of 70%.
# For further imporovement, there are something we can try to improve performance:
# 1. Increase traing set and computing power
# 2. Improving performance by analysing metrics per each target class and falsely predicted data points
# 3. Hyper-parameters tuning
